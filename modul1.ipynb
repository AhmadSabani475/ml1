# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('adult.data.csv')
numerical_stats = df.describe()
print("Statisk Deskriptif untuk kolom numerikal \n", numerical_stats)

# histogram
plt.figure(figsize=(8,6))
sns.histplot(df['age'], kde=True)
plt.title("Histogram of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

#box plot
plt.figure(figsize=(8,6))
sns.boxplot(x="sex", y="hours-per-week", data=df)
plt.title('Box Plot of Hours per week by sex')
plt.xlabel('Sex')
plt.ylabel("Hours per Week")
plt.show()

#Scatter Plot
plt.figure(figsize=(8,6))
sns.scatterplot(x="age", y="capital-gain", data=df)
plt.title('Scatter Plot of Age vs Capital Gain')
plt.xlabel('Age')
plt.ylabel("Capital Gain")
plt.show()

# Line Plot
avg_captial_gain_by_age = df.groupby('age')['capital-gain'].mean()
plt.figure(figsize=(8,6))
plt.plot(avg_captial_gain_by_age.index,avg_captial_gain_by_age.values)
plt.title('Line Plot of Average Capital Gain by Age')
plt.xlabel("age")
plt.ylabel("Average Capital gain")
plt.show()

# Bar Chart
education_counts = df['education'].value_counts()
plt.figure(figsize=(8,6))
plt.bar(education_counts.index, education_counts.values)
plt.xlabel("Tingkat Pendidikan")
plt.ylabel("Jumlah Orang Berdasarkan Tingkat Pendidikan")
plt.xticks(rotation=45, ha='right')
plt.show()

# Pie Chart
sex_counts = df['sex'].value_counts()
plt.figure(figsize=(8,6))
plt.pie(sex_counts.values, labels=sex_counts.index, autopct='%1.1f%%',startangle=90 )
plt.title("Prsentase Jenis Kelamin")
plt.show()

# Donut Chart
race_counts = df['race'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(race_counts.values, labels=race_counts.index, autopct='%1.1f%%',startangle=90, wedgeprops=dict(width=(0.4)) )
plt.title("Prsentase Ras")
plt.show()

# create heatmap
numerical_features = ['age', 'fnlwgt', 'education-num','capital-gain','capital-loss','hours-per-week']
heatmap_data = df[numerical_features].corr()

plt.figure(figsize=(10,8))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# Create a pair plot
sns.pairplot(df[['age',  'education-num','hours-per-week','capital-gain','capital-loss']])
plt.show()

# Create a bubble chart
bubble_data = df[['age', 'hours-per-week', 'capital-gain']]
plt.figure(figsize=(10,8))
plt.scatter(x='age', y='hours-per-week', s='capital-gain',data=bubble_data, alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Hours Per Week')
plt.show()

# univariate analysis for age
plt.figure(figsize=(8,6))
sns.histplot(df['age'], kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# Statisk Deskriptif untuk kolom numerikal
#                  age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('adult.data.csv')
plt.figure(figsize=(8,6))
sns.countplot(x='education-num', hue='salary', data = df)
plt.title(" Plot Education berdasarkan Salarynya")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('adult.data.csv')
categorical_stats = df.select_dtypes(include=['category']).apply(lambda x: x.value_counts(normalize=True) * 100)
print("\n Presntasi Frekuensi untuk kolom kategorikal: \n", categorical_stats)

missing_values = df.isnull().sum()
print("\n jumlah missing values pada tiap kolom:\n", missing_values)
